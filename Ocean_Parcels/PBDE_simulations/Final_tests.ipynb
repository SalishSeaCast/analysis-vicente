# %% [markdown]
# # Final version Tests

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors
import matplotlib.gridspec as gridspec
from matplotlib.colors import ListedColormap
from matplotlib.path import Path
from shapely.geometry import Polygon, Point
from shapely.plotting import plot_polygon

# %%
path = {'coords' : '/ocean/vvalenzuela/MOAD/grid/coordinates_seagrid_SalishSea201702.nc',
'mask' : '/ocean/vvalenzuela/MOAD/grid2/mesh_mask202108_TDV.nc',
'bathy' : '/ocean/vvalenzuela/MOAD/grid/bathymetry_202108.nc'
}
#
coords = xr.open_dataset(path['coords'], decode_times=False)
mask = xr.open_dataset(path['mask'])
bathy = xr.open_dataset(path['bathy'])

# %%
colors_0 = [(0, 0, 0, 1),  # Black for land
          (0, 0, 0, 0)]  # Transparent for water
cmap = ListedColormap(colors_0)

# %%
def finder2(target_lat, target_lon, mask=mask):
    lat = mask.nav_lat
    lon = mask.nav_lon
    distance = ((lat - target_lat)**2 + (lon - target_lon)**2)**0.5
    nearest_index = distance.argmin()
    return int(nearest_index // lon.shape[1]), int(nearest_index % lon.shape[1])

# %%
Nx1_1, Ny1_1 = [132,170], [665,680]
Nx1_2, Ny1_2 = [170,200], [680,620]
Nx1_3, Ny1_3 = [135,200], [620,620]
#
polygon_coords_N1 = [
    (Nx1_1[0], Ny1_1[0]),
    (Nx1_1[1], Ny1_1[1]),
    (Nx1_2[1], Ny1_2[1]),
    (Nx1_3[1], Ny1_3[1]),
    (Nx1_3[0], Ny1_3[0])
]
polygon_N1 = Polygon(polygon_coords_N1)
#
N1_lon_1, N1_lat_1 = [mask.nav_lon[Ny1_1[0],Nx1_1[0]].values, mask.nav_lon[Ny1_1[1],Nx1_1[1]].values], [mask.nav_lat[Ny1_1[0],Nx1_1[0]].values, mask.nav_lat[Ny1_1[1],Nx1_1[1]].values]
N1_lon_2, N1_lat_2 = [mask.nav_lon[Ny1_2[0],Nx1_2[0]].values, mask.nav_lon[Ny1_2[1],Nx1_2[1]].values], [mask.nav_lat[Ny1_2[0],Nx1_2[0]].values, mask.nav_lat[Ny1_2[1],Nx1_2[1]].values]
N1_lon_3, N1_lat_3 = [mask.nav_lon[Ny1_3[0],Nx1_3[0]].values, mask.nav_lon[Ny1_3[1],Nx1_3[1]].values], [mask.nav_lat[Ny1_3[0],Nx1_3[0]].values, mask.nav_lat[Ny1_3[1],Nx1_3[1]].values]
#
polygon_lon_lat_N1 = [
    (N1_lon_1[0], N1_lat_1[0]),
    (N1_lon_1[1], N1_lat_1[1]),
    (N1_lon_2[1], N1_lat_2[1]),
    (N1_lon_3[1], N1_lat_3[1]),
    (N1_lon_3[0], N1_lat_3[0])
]
polygon_coors_N1 = Polygon(polygon_lon_lat_N1)

# %%
Sx1_1, Sy1_1 = [202,292], [505,505]
Sx1_2, Sy1_2 = [300,315], [505,480]
Sx1_3, Sy1_3 = [210,238], [500,465]
Sx1_4, Sy1_4 = [238,245], [465,410]
Sx1_5, Sy1_5 = [302, 280], [410, 470]
Sx1_6, Sy1_6 = [245,302], [410,410]
#
polygon_coords_S1 = [
    (Sx1_1[0], Sy1_1[0]),
    (Sx1_1[1], Sy1_1[1]),
    (Sx1_5[1], Sy1_5[1]),
    (Sx1_4[0], Sy1_4[0])
]
polygon_S1 = Polygon(polygon_coords_S1)
#
S1_lon_1, S1_lat_1 = [mask.nav_lon[Sy1_1[0],Sx1_1[0]].values, mask.nav_lon[Sy1_1[1],Sx1_1[1]].values], [mask.nav_lat[Sy1_1[0],Sx1_1[0]].values, mask.nav_lat[Sy1_1[1],Sx1_1[1]].values]
S1_lon_2, S1_lat_2 = [mask.nav_lon[Sy1_2[0],Sx1_2[0]].values, mask.nav_lon[Sy1_2[1],Sx1_2[1]].values], [mask.nav_lat[Sy1_2[0],Sx1_2[0]].values, mask.nav_lat[Sy1_2[1],Sx1_2[1]].values]
S1_lon_3, S1_lat_3 = [mask.nav_lon[Sy1_3[0],Sx1_3[0]].values, mask.nav_lon[Sy1_3[1],Sx1_3[1]].values], [mask.nav_lat[Sy1_3[0],Sx1_3[0]].values, mask.nav_lat[Sy1_3[1],Sx1_3[1]].values]
S1_lon_4, S1_lat_4 = [mask.nav_lon[Sy1_4[0],Sx1_4[0]].values, mask.nav_lon[Sy1_4[1],Sx1_4[1]].values], [mask.nav_lat[Sy1_4[0],Sx1_4[0]].values, mask.nav_lat[Sy1_4[1],Sx1_4[1]].values]
S1_lon_5, S1_lat_5 = [mask.nav_lon[Sy1_5[0],Sx1_5[0]].values, mask.nav_lon[Sy1_5[1],Sx1_5[1]].values], [mask.nav_lat[Sy1_5[0],Sx1_5[0]].values, mask.nav_lat[Sy1_5[1],Sx1_5[1]].values]
S1_lon_6, S1_lat_6 = [mask.nav_lon[Sy1_6[0],Sx1_6[0]].values, mask.nav_lon[Sy1_6[1],Sx1_6[1]].values], [mask.nav_lat[Sy1_6[0],Sx1_6[0]].values, mask.nav_lat[Sy1_6[1],Sx1_6[1]].values]
#
polygon_lon_lat_S1 = [
    (S1_lon_1[0], S1_lat_1[0]),
    (S1_lon_1[1], S1_lat_1[1]),
    (S1_lon_5[1], S1_lat_5[1]),
    (S1_lon_4[0], S1_lat_4[0])
]
polygon_coors_S1 = Polygon(polygon_lon_lat_S1)

# %%
def volume_region_50m_bottom(polygon):
    mesh = xr.open_dataset(path['mask'])
    volume = mesh['volume']
    mask = xr.open_dataset(path['mask'])['tmask'][0]
    #
    depths = mesh['gdept_1d'][0] 
    depth_condition = depths >= 50
    # 
    depth_mask_3d = depth_condition.values[:, np.newaxis, np.newaxis]
    #    
    x = volume['x']  
    y = volume['y'] 
    #
    xx, yy = np.meshgrid(x, y)
    #
    # 2D Polygon Mask
    polygon_mask_2d = np.array([
        [polygon.contains(Point(xx[j, i], yy[j, i])) for i in range(len(x))]
        for j in range(len(y))
    ])

    # to 3D
    nz = volume.sizes['z']
    polygon_mask_3d = np.repeat(polygon_mask_2d[np.newaxis, :, :], nz, axis=0)

    # inside polygon  + in water + > 50 m
    combined_mask = (polygon_mask_3d & (mask.values == 1) & depth_mask_3d)

    # Applying mask
    mask_da = xr.DataArray(combined_mask, dims=volume.dims, coords=volume.coords)
    volume_in_polygon_water = volume.where(mask_da).sum().item()
    
    return volume_in_polygon_water

# %%
volume_N1 = volume_region_50m_bottom(polygon_N1)
volume_S1 = volume_region_50m_bottom(polygon_S1)
print(volume_N1/1e9, 'km^3')
print(volume_S1/1e9, 'km^3')
# Out:
# 64.30395579 km^3
# 109.140915985 km^3

# %%
def polygon_definition_data_colloidal(ds, region_polygon,  depth_min=50):
#
    lons = ds['lon'].values
    lats = ds['lat'].values
    depths = ds['z'].values
    statuses = ds['status'].values
    #
    points_flat = np.column_stack((lons.ravel(), lats.ravel()))
    poly_path = Path(region_polygon)
    # points inside polygon
    inside_mask_flat = poly_path.contains_points(points_flat)
    inside_mask = inside_mask_flat.reshape(lons.shape)
    # >= 50 mask
    deep_mask = depths >= depth_min
    #deep_mask = depths >= depth_min
    # Colloidal status 
    status_mask = np.isin(statuses, 2) 
    #
    valid_mask = inside_mask & deep_mask & status_mask
    #
    counts = np.sum(valid_mask, axis=0) 
    #
    times = ds['time'].values
    time_index = np.nanmax(times, axis=0) 
    #
    return pd.DataFrame({'count': counts}, index=time_index)

# %%
def particles_amount(
    lons, lats, mask=mask, num_lon=200, num_lat=200
):
    nav_lon = mask['nav_lon'].values
    nav_lat = mask['nav_lat'].values

    lon_edges = np.linspace(nav_lon.min(), nav_lon.max(), num_lon + 1)
    lat_edges = np.linspace(nav_lat.min(), nav_lat.max(), num_lat + 1)

    lon_centers = (lon_edges[:-1] + lon_edges[1:]) / 2
    lat_centers = (lat_edges[:-1] + lat_edges[1:]) / 2

    counts, xedges, yedges = np.histogram2d(
        lons, lats,
        bins=[lon_edges, lat_edges]
    )

    df = pd.DataFrame(
        counts.T,  
        index=lat_centers,
        columns=lon_centers
    )

    Xcenters, Ycenters = np.meshgrid(lon_centers, lat_centers)

    flat_lon = Xcenters.ravel()
    flat_lat = Ycenters.ravel()

    ii_sed = np.zeros(flat_lon.size, dtype=int)
    jj_sed = np.zeros(flat_lon.size, dtype=int)

    for k in range(flat_lon.size):
        jj, ii = finder2(flat_lat[k], flat_lon[k], mask)
        ii_sed[k] = ii
        jj_sed[k] = jj

    ii_sed = ii_sed.reshape(Xcenters.shape)
    jj_sed = jj_sed.reshape(Ycenters.shape)

    grid_indices = (ii_sed, jj_sed)

    raw_hist = (counts, xedges, yedges)

    return df, raw_hist, grid_indices

# %% [markdown]
# # Concetrations per simulation (October 2007)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V1_year_1.nc').isel(obs=slice(2184, 2432)) as data_V1:
    #     
    counts_S1_V1 = polygon_definition_data_colloidal(data_V1, polygon_lon_lat_S1)
    counts_N1_V1 = polygon_definition_data_colloidal(data_V1, polygon_lon_lat_N1)
    concentration_S1_V1 = np.sum(counts_S1_V1) / volume_S1 / len(data_V1['obs'])
    concentration_N1_V1 = np.sum(counts_N1_V1) / volume_N1 / len(data_V1['obs'])
    ratio_S1_N1_V1 = concentration_S1_V1 / concentration_N1_V1
    #
print('Concentration at S1 (V1) = ', concentration_S1_V1)
print('Concentration at N1 (V1) = ', concentration_N1_V1)
print('Ratio S1/N1 (V1) = ', ratio_S1_N1_V1)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V2_year_1.nc').isel(obs=slice(2184, 2432)) as data_V2:
    #     
    counts_S1_V2 = polygon_definition_data_colloidal(data_V2, polygon_lon_lat_S1)
    counts_N1_V2 = polygon_definition_data_colloidal(data_V2, polygon_lon_lat_N1)
    concentration_S1_V2 = np.sum(counts_S1_V2) / volume_S1 / len(data_V2['obs'])
    concentration_N1_V2 = np.sum(counts_N1_V2) / volume_N1 / len(data_V2['obs'])
    ratio_S1_N1_V2 = concentration_S1_V2 / concentration_N1_V2
    #
print('Concentration at S1 (V2) = ', concentration_S1_V2)
print('Concentration at N1 (V2) = ', concentration_N1_V2)
print('Ratio S1/N1 (V2) = ', ratio_S1_N1_V2)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V3_year_1.nc').isel(obs=slice(2184, 2432)) as data_V3:
    #     
    counts_S1_V3 = polygon_definition_data_colloidal(data_V3, polygon_lon_lat_S1)
    counts_N1_V3 = polygon_definition_data_colloidal(data_V3, polygon_lon_lat_N1)
    concentration_S1_V3 = np.sum(counts_S1_V3) / volume_S1 / len(data_V3['obs'])
    concentration_N1_V3 = np.sum(counts_N1_V3) / volume_N1 / len(data_V3['obs'])
    ratio_S1_N1_V3 = concentration_S1_V3 / concentration_N1_V3
    #
print('Concentration at S1 (V3) = ', concentration_S1_V3)
print('Concentration at N1 (V3) = ', concentration_N1_V3)
print('Ratio S1/N1 (V3) = ', ratio_S1_N1_V3)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V4_year_1.nc').isel(obs=slice(2184, 2432)) as data_V4:
    #     
    counts_S1_V4 = polygon_definition_data_colloidal(data_V4, polygon_lon_lat_S1)
    counts_N1_V4 = polygon_definition_data_colloidal(data_V4, polygon_lon_lat_N1)
    concentration_S1_V4 = np.sum(counts_S1_V4) / volume_S1 / len(data_V4['obs'])
    concentration_N1_V4 = np.sum(counts_N1_V4) / volume_N1 / len(data_V4['obs'])
    ratio_S1_N1_V4 = concentration_S1_V4 / concentration_N1_V4
    #
print('Concentration at S1 (V4) = ', concentration_S1_V4)
print('Concentration at N1 (V4) = ', concentration_N1_V4)
print('Ratio S1/N1 (V4) = ', ratio_S1_N1_V4)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V5_year_1.nc').isel(obs=slice(2184, 2432)) as data_V5:
    #     
    counts_S1_V5 = polygon_definition_data_colloidal(data_V5, polygon_lon_lat_S1)
    counts_N1_V5 = polygon_definition_data_colloidal(data_V5, polygon_lon_lat_N1)
    concentration_S1_V5 = np.sum(counts_S1_V5) / volume_S1 / len(data_V5['obs'])
    concentration_N1_V5 = np.sum(counts_N1_V5) / volume_N1 / len(data_V5['obs'])
    ratio_S1_N1_V5 = concentration_S1_V5 / concentration_N1_V5
    #
print('Concentration at S1 (V5) = ', concentration_S1_V5)
print('Concentration at N1 (V5) = ', concentration_N1_V5)
print('Ratio S1/N1 (V5) = ', ratio_S1_N1_V5)

# %%
def proportions(data):
    status = data.status.values
    lat = data.lat.values
    lon = data.lon.values

    valid_mask = np.isfinite(status) & np.isfinite(lat) & np.isfinite(lon)

    total_arr = np.sum(valid_mask, axis=0).astype(float)


    def count_status(condition):
        return np.sum(condition & valid_mask, axis=0)

    initial = count_status(status < 0)
    sewage_water = count_status(status == 1)
    colloidal_water = count_status(status == 2)
    marine_water = count_status(status == 3)
    out_jdf = count_status(status == 7)
    out_js = count_status(status == 8)
    sewage_sediment = count_status(status == 11)
    colloidal_sediment = count_status(status == 12)
    marine_sediment = count_status(status == 13)

    with np.errstate(divide='ignore', invalid='ignore'):
        p_initial = (initial / total_arr) * 100
        p_colloidal_water = (colloidal_water / total_arr) * 100
        p_marine_water = (marine_water / total_arr) * 100
        p_sewage_water = (sewage_water / total_arr) * 100
        p_colloidal_sediment = (colloidal_sediment / total_arr) * 100
        p_marine_sediment = (marine_sediment / total_arr) * 100
        p_sewage_sediment = (sewage_sediment / total_arr) * 100
        p_out_jdf = (out_jdf / total_arr) * 100
        p_out_js = (out_js / total_arr) * 100

    data_proportions = pd.DataFrame({
        'initial': p_initial,
        'colloidal_water': p_colloidal_water,
        'marine_water': p_marine_water,
        'sewage_water': p_sewage_water,
        'colloidal_sediment': p_colloidal_sediment,
        'marine_sediment': p_marine_sediment,
        'sewage_sediment': p_sewage_sediment,
        'out_jdf': p_out_jdf,
        'out_js': p_out_js,
        'total_len': total_arr
    })

    return data_proportions

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V1_year_1.nc') as data_V1:
    p_V1 = proportions(data_V1)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V2_year_1.nc') as data_V2:
    p_V2 = proportions(data_V2)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V3_year_1.nc') as data_V3:
    p_V3 = proportions(data_V3)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V4_year_1.nc') as data_V4:
    p_V4 = proportions(data_V4)

# %%
fig, ax = plt.subplots(4,1, figsize = (12,30))
ax[0].plot(p_V1['colloidal_water'], 'k', alpha =.2)
ax[0].plot(p_V2['colloidal_water'], 'b', alpha =.2)
ax[0].plot(p_V3['colloidal_water'], 'g', alpha =.2)
ax[0].plot(p_V4['colloidal_water'], 'r', alpha =.2)
#
ax[1].plot(p_V1['marine_water'], 'k', alpha =.2)
ax[1].plot(p_V2['marine_water'], 'b', alpha =.2)
ax[1].plot(p_V3['marine_water'], 'g', alpha =.2)
ax[1].plot(p_V4['marine_water'], 'r', alpha =.2)
#
ax[2].plot(p_V1['marine_sediment'], '--k', alpha =.2)
ax[2].plot(p_V2['marine_sediment'], '--b', alpha =.2)
ax[2].plot(p_V3['marine_sediment'], '--g', alpha =.2)
ax[2].plot(p_V4['marine_sediment'], '--r', alpha =.2)
#
ax[2].plot(p_V1['colloidal_sediment'], '-k', alpha =.7)
ax[2].plot(p_V2['colloidal_sediment'], '-b', alpha =.7)
ax[2].plot(p_V3['colloidal_sediment'], '-g', alpha =.7)
ax[2].plot(p_V4['colloidal_sediment'], '-r', alpha =.7)
#
ax[3].plot(p_V1['out_jdf'], 'k', alpha =.2)
ax[3].plot(p_V2['out_jdf'], 'b', alpha =.2)
ax[3].plot(p_V3['out_jdf'], 'g', alpha =.2)
ax[3].plot(p_V4['out_jdf'], 'r', alpha =.2)

# %%
def particles_amount(
    lons, lats, mask=mask, num_lon=200, num_lat=200
):
    nav_lon = mask['nav_lon'].values
    nav_lat = mask['nav_lat'].values

    lon_edges = np.linspace(nav_lon.min(), nav_lon.max(), num_lon + 1)
    lat_edges = np.linspace(nav_lat.min(), nav_lat.max(), num_lat + 1)

    lon_centers = (lon_edges[:-1] + lon_edges[1:]) / 2
    lat_centers = (lat_edges[:-1] + lat_edges[1:]) / 2

    counts, xedges, yedges = np.histogram2d(
        lons, lats,
        bins=[lon_edges, lat_edges]
    )

    df = pd.DataFrame(
        counts.T,  
        index=lat_centers,
        columns=lon_centers
    )

    Xcenters, Ycenters = np.meshgrid(lon_centers, lat_centers)

    flat_lon = Xcenters.ravel()
    flat_lat = Ycenters.ravel()

    ii_sed = np.zeros(flat_lon.size, dtype=int)
    jj_sed = np.zeros(flat_lon.size, dtype=int)

    for k in range(flat_lon.size):
        jj, ii = finder2(flat_lat[k], flat_lon[k], mask)
        ii_sed[k] = ii
        jj_sed[k] = jj

    ii_sed = ii_sed.reshape(Xcenters.shape)
    jj_sed = jj_sed.reshape(Ycenters.shape)

    grid_indices = (ii_sed, jj_sed)

    raw_hist = (counts, xedges, yedges)

    return df, raw_hist, grid_indices

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V1_year_1.nc').isel(obs=slice(2184, 2432)) as data_V1:
    #
    wc_V1 = data_V1.where(data_V1['status'] == 2)
    #
    amount_V1, _, grid_ijV1 = particles_amount(wc_V1['lon'].values.flatten(), wc_V1['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V1.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V1_plot = ax.pcolormesh(grid_ijV1[0], grid_ijV1[1], amount_V1,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV1[0], grid_ijV1[1], amount_V1, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V1 = plt.colorbar(V1_plot, ax = ax)
    cbar_V1.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V1.ax.hlines(
            lev, 
            *cbar_V1.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.005 Pa, Ads. = 0.1, MC = 0.2, Vel. C. = Hx1.2')
    plt.tight_layout()

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V2_year_1.nc').isel(obs=slice(2184, 2432)) as data_V2:
    #
    wc_V2 = data_V2.where(data_V2['status'] == 2)
    #
    amount_V2, _, grid_ijV2 = particles_amount(wc_V2['lon'].values.flatten(), wc_V2['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V2.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V2_plot = ax.pcolormesh(grid_ijV2[0], grid_ijV2[1], amount_V2,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV2[0], grid_ijV2[1], amount_V2, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V2 = plt.colorbar(V2_plot, ax = ax)
    cbar_V2.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V2.ax.hlines(
            lev, 
            *cbar_V2.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.0025 Pa, Ads. = 0.05, MC = 0.2, Vel. C. = N')
    plt.tight_layout()

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V3_year_1.nc').isel(obs=slice(2184, 2432)) as data_V3:
    #
    wc_V3 = data_V3.where(data_V3['status'] == 2)
    #
    amount_V3, _, grid_ijV3 = particles_amount(wc_V3['lon'].values.flatten(), wc_V3['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V3.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V3_plot = ax.pcolormesh(grid_ijV3[0], grid_ijV3[1], amount_V3,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV3[0], grid_ijV3[1], amount_V3, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V3 = plt.colorbar(V3_plot, ax = ax)
    cbar_V3.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V3.ax.hlines(
            lev, 
            *cbar_V3.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.005 Pa, Ads. = 0.05, MC = 0.2, Vel. C. = Hx1.2')
    plt.tight_layout()

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V4_year_1.nc').isel(obs=slice(2184, 2432)) as data_V4:
    #
    wc_V4 = data_V4.where(data_V4['status'] == 2)
    #
    amount_V4, _, grid_ijV4 = particles_amount(wc_V4['lon'].values.flatten(), wc_V4['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V4.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V4_plot = ax.pcolormesh(grid_ijV4[0], grid_ijV4[1], amount_V4,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV4[0], grid_ijV4[1], amount_V4, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V4 = plt.colorbar(V4_plot, ax = ax)
    cbar_V4.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V4.ax.hlines(
            lev, 
            *cbar_V4.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.001 Pa, Ads. = 0.01, MC = 0.2, Vel. C. = Hx1.2')
    plt.tight_layout()

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V5_year_1.nc').isel(obs=slice(2184, 2432)) as data_V5:
    #
    wc_V5 = data_V5.where(data_V5['status'] == 2)
    #
    amount_V5, _, grid_ijV5 = particles_amount(wc_V5['lon'].values.flatten(), wc_V5['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V5.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V5_plot = ax.pcolormesh(grid_ijV5[0], grid_ijV5[1], amount_V5,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV5[0], grid_ijV5[1], amount_V5, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V5 = plt.colorbar(V5_plot, ax = ax)
    cbar_V5.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V5.ax.hlines(
            lev, 
            *cbar_V5.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.001 Pa, Ads. = 0.1, MC = 0.2, Vel. C. = Hx1.2')
    plt.tight_layout()

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V1_year_1.nc') as data_V1:
    #     
    counts_S1_V1 = polygon_definition_data_colloidal(data_V1, polygon_lon_lat_S1)
    counts_N1_V1 = polygon_definition_data_colloidal(data_V1, polygon_lon_lat_N1)
    concentration_S1_V1 = counts_S1_V1 / volume_S1 / len(data_V1['obs'])
    concentration_N1_V1 = counts_N1_V1 / volume_N1 / len(data_V1['obs'])
    ratio_S1_N1_V1 = concentration_S1_V1 / concentration_N1_V1

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V2_year_1.nc') as data_V2:
    #     
    counts_S1_V2 = polygon_definition_data_colloidal(data_V2, polygon_lon_lat_S1)
    counts_N1_V2 = polygon_definition_data_colloidal(data_V2, polygon_lon_lat_N1)
    concentration_S1_V2 = counts_S1_V2 / volume_S1 / len(data_V2['obs'])
    concentration_N1_V2 = counts_N1_V2 / volume_N1 / len(data_V2['obs'])
    ratio_S1_N1_V2 = concentration_S1_V2 / concentration_N1_V2

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V2_year_2.nc') as data_V2_2:
    #     
    counts_S1_V2_2 = polygon_definition_data_colloidal(data_V2_2, polygon_lon_lat_S1)
    counts_N1_V2_2 = polygon_definition_data_colloidal(data_V2_2, polygon_lon_lat_N1)
    concentration_S1_V2_2 = counts_S1_V2_2 / volume_S1 / len(data_V2_2['obs'])
    concentration_N1_V2_2 = counts_N1_V2_2 / volume_N1 / len(data_V2_2['obs'])
    ratio_S1_N1_V2_2 = concentration_S1_V2_2 / concentration_N1_V2_2

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V3_year_1.nc') as data_V3:
    #     
    counts_S1_V3 = polygon_definition_data_colloidal(data_V3, polygon_lon_lat_S1)
    counts_N1_V3 = polygon_definition_data_colloidal(data_V3, polygon_lon_lat_N1)
    concentration_S1_V3 = counts_S1_V3 / volume_S1 / len(data_V3['obs'])
    concentration_N1_V3 = counts_N1_V3 / volume_N1 / len(data_V3['obs'])
    ratio_S1_N1_V3 = concentration_S1_V3 / concentration_N1_V3
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V4_year_1.nc') as data_V4:
    #     
    counts_S1_V4 = polygon_definition_data_colloidal(data_V4, polygon_lon_lat_S1)
    counts_N1_V4 = polygon_definition_data_colloidal(data_V4, polygon_lon_lat_N1)
    concentration_S1_V4 = counts_S1_V4 / volume_S1 / len(data_V4['obs'])
    concentration_N1_V4 = counts_N1_V4 / volume_N1 / len(data_V4['obs'])
    ratio_S1_N1_V4 = concentration_S1_V4 / concentration_N1_V4

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V4_year_2.nc') as data_V4_2:
    #     
    counts_S1_V4_2 = polygon_definition_data_colloidal(data_V4_2, polygon_lon_lat_S1)
    counts_N1_V4_2 = polygon_definition_data_colloidal(data_V4_2, polygon_lon_lat_N1)
    concentration_S1_V4_2 = counts_S1_V4_2 / volume_S1 / len(data_V4_2['obs'])
    concentration_N1_V4_2 = counts_N1_V4_2 / volume_N1 / len(data_V4_2['obs'])
    ratio_S1_N1_V4_2 = concentration_S1_V4_2 / concentration_N1_V4_2

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V5_year_1.nc') as data_V5:
    #     
    counts_S1_V5 = polygon_definition_data_colloidal(data_V5, polygon_lon_lat_S1)
    counts_N1_V5 = polygon_definition_data_colloidal(data_V5, polygon_lon_lat_N1)
    concentration_S1_V5 = counts_S1_V5 / volume_S1 / len(data_V5['obs'])
    concentration_N1_V5 = counts_N1_V5 / volume_N1 / len(data_V5['obs'])
    ratio_S1_N1_V5 = concentration_S1_V5 / concentration_N1_V5

# %%
fig, ax = plt.subplots(3,1, figsize = (14,12))
#ax[0].plot(concentration_S1_V1, 'm', alpha = .7, label = 'V1')
ax[0].plot(concentration_S1_V2, 'tab:brown', alpha = .7, label = 'V2')
ax[0].plot(concentration_S1_V2_2, 'tab:brown', alpha = .7)
#ax[0].plot(concentration_S1_V3, 'k', alpha = .7, label = 'V3')
ax[0].plot(concentration_S1_V4, 'tab:orange', alpha = .7, label = 'V4')
ax[0].plot(concentration_S1_V4_2, 'tab:orange', alpha = .7)
#ax[0].plot(concentration_S1_V5, 'tab:purple', alpha = .7, label = 'V5')
ax[0].set_xlim(ratio_S1_N1_V2.index[0],ratio_S1_N1_V2_2.index[-1])

ax[0].set_ylabel('[S1]')
#
#ax[1].plot(concentration_N1_V1, 'm', alpha = .7, label = 'V1')
ax[1].plot(concentration_N1_V2, 'tab:brown', alpha = .7, label = 'V2')
ax[1].plot(concentration_N1_V2_2, 'tab:brown', alpha = .7)
#ax[1].plot(concentration_N1_V3, 'k', alpha = .7, label = 'V3')
ax[1].plot(concentration_N1_V4, 'tab:orange', alpha = .7, label = 'V4')
ax[1].plot(concentration_N1_V4_2, 'tab:orange', alpha = .7)
#ax[1].plot(concentration_N1_V5, 'tab:purple', alpha = .7, label = 'V5')
ax[1].set_xlim(ratio_S1_N1_V2.index[0],ratio_S1_N1_V2_2.index[-1])

ax[1].set_ylabel('[N1]')
#
#ax[2].plot(ratio_S1_N1_V1, 'm', alpha = .7, label = 'V1')
ax[2].plot(ratio_S1_N1_V2, 'tab:brown', alpha = .7, label = 'V2')
ax[2].plot(ratio_S1_N1_V2_2, 'tab:brown', alpha = .7)
#ax[2].plot(ratio_S1_N1_V3, 'k', alpha = .7, label = 'V3')
ax[2].plot(ratio_S1_N1_V4, 'tab:orange', alpha = .7, label = 'V4')
ax[2].plot(ratio_S1_N1_V4_2, 'tab:orange', alpha = .7)
#ax[2].plot(ratio_S1_N1_V5, 'tab:purple', alpha = .7, label = 'V5')
ax[2].set_xlim(ratio_S1_N1_V2.index[0],ratio_S1_N1_V2_2.index[-1])
ax[2].set_ylim(0, 100)

ax[2].set_ylabel('[S1] / [N1]')
#
for axis in ax:
    axis.grid(linestyle = '--')
    axis.legend(loc = 'upper left', ncol = 5, fontsize = 16)
#
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
concentration_S1_V2_year2 = pd.DataFrame(concentration_S1_V2['count'].values + concentration_S1_V2_2['count'].values, index = concentration_S1_V2_2.index)
concentration_N1_V2_year2 = pd.DataFrame(concentration_N1_V2['count'].values + concentration_N1_V2_2['count'].values, index = concentration_N1_V2_2.index)
ratio_S1_N1_V2_year2 = pd.DataFrame(concentration_S1_V2_year2/concentration_N1_V2_year2, index = concentration_S1_V2_year2.index)
#
concentration_S1_V4_year2 = pd.DataFrame(concentration_S1_V4['count'].values + concentration_S1_V4_2['count'].values, index = concentration_S1_V4_2.index)
concentration_N1_V4_year2 = pd.DataFrame(concentration_N1_V4['count'].values + concentration_N1_V4_2['count'].values, index = concentration_N1_V4_2.index)
ratio_S1_N1_V4_year2 = pd.DataFrame(concentration_S1_V4_year2/concentration_N1_V4_year2, index = concentration_S1_V4_year2.index)

# %%
fig, ax = plt.subplots(3,1, figsize = (14,12))
#ax[0].plot(concentration_S1_V1, 'm', alpha = .7, label = 'V1')
ax[0].plot(concentration_S1_V2, 'tab:brown', alpha = .7, label = 'V2')
ax[0].plot(concentration_S1_V2_year2, 'tab:brown', alpha = .7)
#ax[0].plot(concentration_S1_V3, 'k', alpha = .7, label = 'V3')
ax[0].plot(concentration_S1_V4, 'tab:orange', alpha = .7, label = 'V4')
ax[0].plot(concentration_S1_V4_year2, 'tab:orange', alpha = .7)
#ax[0].plot(concentration_S1_V5, 'tab:purple', alpha = .7, label = 'V5')
ax[0].set_xlim(ratio_S1_N1_V2.index[0],ratio_S1_N1_V2_2.index[-1])

ax[0].set_ylabel('[S1]')
#
#ax[1].plot(concentration_N1_V1, 'm', alpha = .7, label = 'V1')
ax[1].plot(concentration_N1_V2, 'tab:brown', alpha = .7, label = 'V2')
ax[1].plot(concentration_N1_V2_year2, 'tab:brown', alpha = .7)
#ax[1].plot(concentration_N1_V3, 'k', alpha = .7, label = 'V3')
ax[1].plot(concentration_N1_V4, 'tab:orange', alpha = .7, label = 'V4')
ax[1].plot(concentration_N1_V4_year2, 'tab:orange', alpha = .7)
#ax[1].plot(concentration_N1_V5, 'tab:purple', alpha = .7, label = 'V5')
ax[1].set_xlim(ratio_S1_N1_V2.index[0],ratio_S1_N1_V2_2.index[-1])

ax[1].set_ylabel('[N1]')
#
#ax[2].plot(ratio_S1_N1_V1, 'm', alpha = .7, label = 'V1')
ax[2].plot(ratio_S1_N1_V2, 'tab:brown', alpha = .7, label = 'V2')
ax[2].plot(ratio_S1_N1_V2_year2, 'tab:brown', alpha = .7)
#ax[2].plot(ratio_S1_N1_V3, 'k', alpha = .7, label = 'V3')
ax[2].plot(ratio_S1_N1_V4, 'tab:orange', alpha = .7, label = 'V4')
ax[2].plot(ratio_S1_N1_V4_year2, 'tab:orange', alpha = .7)
#ax[2].plot(ratio_S1_N1_V5, 'tab:purple', alpha = .7, label = 'V5')
ax[2].set_xlim(ratio_S1_N1_V2.index[0],ratio_S1_N1_V2_2.index[-1])
ax[2].set_ylim(0, 100)

ax[2].set_ylabel('[S1] / [N1]')
#
for axis in ax:
    axis.grid(linestyle = '--')
    axis.legend(loc = 'upper left', ncol = 5, fontsize = 16)
#

# %% [markdown]
# # Concentrations December 2007

# %%
aa = xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V1_year_1.nc')

# %%
aa['time'][0,2672].values

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V1_year_1.nc').isel(obs=slice(2672, None)) as data_V1:
    #     
    counts_S1_V1 = polygon_definition_data_colloidal(data_V1, polygon_lon_lat_S1)
    counts_N1_V1 = polygon_definition_data_colloidal(data_V1, polygon_lon_lat_N1)
    concentration_S1_V1 = np.sum(counts_S1_V1) / volume_S1 / len(data_V1['obs'])
    concentration_N1_V1 = np.sum(counts_N1_V1) / volume_N1 / len(data_V1['obs'])
    ratio_S1_N1_V1 = concentration_S1_V1 / concentration_N1_V1
    #
print('Concentration at S1 (V1) = ', concentration_S1_V1)
print('Concentration at N1 (V1) = ', concentration_N1_V1)
print('Ratio S1/N1 (V1) = ', ratio_S1_N1_V1)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V2_year_1.nc').isel(obs=slice(2672, None)) as data_V2:
    #     
    counts_S1_V2 = polygon_definition_data_colloidal(data_V2, polygon_lon_lat_S1)
    counts_N1_V2 = polygon_definition_data_colloidal(data_V2, polygon_lon_lat_N1)
    concentration_S1_V2 = np.sum(counts_S1_V2) / volume_S1 / len(data_V2['obs'])
    concentration_N1_V2 = np.sum(counts_N1_V2) / volume_N1 / len(data_V2['obs'])
    ratio_S1_N1_V2 = concentration_S1_V2 / concentration_N1_V2
    #
print('Concentration at S1 (V2) = ', concentration_S1_V2)
print('Concentration at N1 (V2) = ', concentration_N1_V2)
print('Ratio S1/N1 (V2) = ', ratio_S1_N1_V2)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V3_year_1.nc').isel(obs=slice(2672, None)) as data_V3:
    #     
    counts_S1_V3 = polygon_definition_data_colloidal(data_V3, polygon_lon_lat_S1)
    counts_N1_V3 = polygon_definition_data_colloidal(data_V3, polygon_lon_lat_N1)
    concentration_S1_V3 = np.sum(counts_S1_V3) / volume_S1 / len(data_V3['obs'])
    concentration_N1_V3 = np.sum(counts_N1_V3) / volume_N1 / len(data_V3['obs'])
    ratio_S1_N1_V3 = concentration_S1_V3 / concentration_N1_V3
    #
print('Concentration at S1 (V3) = ', concentration_S1_V3)
print('Concentration at N1 (V3) = ', concentration_N1_V3)
print('Ratio S1/N1 (V3) = ', ratio_S1_N1_V3)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V4_year_1.nc').isel(obs=slice(2672, None)) as data_V4:
    #     
    counts_S1_V4 = polygon_definition_data_colloidal(data_V4, polygon_lon_lat_S1)
    counts_N1_V4 = polygon_definition_data_colloidal(data_V4, polygon_lon_lat_N1)
    concentration_S1_V4 = np.sum(counts_S1_V4) / volume_S1 / len(data_V4['obs'])
    concentration_N1_V4 = np.sum(counts_N1_V4) / volume_N1 / len(data_V4['obs'])
    ratio_S1_N1_V4 = concentration_S1_V4 / concentration_N1_V4
    #
print('Concentration at S1 (V4) = ', concentration_S1_V4)
print('Concentration at N1 (V4) = ', concentration_N1_V4)
print('Ratio S1/N1 (V4) = ', ratio_S1_N1_V4)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V5_year_1.nc').isel(obs=slice(2672, None)) as data_V5:
    #     
    counts_S1_V5 = polygon_definition_data_colloidal(data_V5, polygon_lon_lat_S1)
    counts_N1_V5 = polygon_definition_data_colloidal(data_V5, polygon_lon_lat_N1)
    concentration_S1_V5 = np.sum(counts_S1_V5) / volume_S1 / len(data_V5['obs'])
    concentration_N1_V5 = np.sum(counts_N1_V5) / volume_N1 / len(data_V5['obs'])
    ratio_S1_N1_V5 = concentration_S1_V5 / concentration_N1_V5
    #
print('Concentration at S1 (V5) = ', concentration_S1_V5)
print('Concentration at N1 (V5) = ', concentration_N1_V5)
print('Ratio S1/N1 (V5) = ', ratio_S1_N1_V5)

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V1_year_1.nc').isel(obs=slice(2672, None)) as data_V1:
    #
    wc_V1 = data_V1.where(data_V1['status'] == 2)
    #
    amount_V1, _, grid_ijV1 = particles_amount(wc_V1['lon'].values.flatten(), wc_V1['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V1.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V1_plot = ax.pcolormesh(grid_ijV1[0], grid_ijV1[1], amount_V1,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV1[0], grid_ijV1[1], amount_V1, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V1 = plt.colorbar(V1_plot, ax = ax)
    cbar_V1.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V1.ax.hlines(
            lev, 
            *cbar_V1.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.005 Pa, Ads. = 0.1, MC = 0.2, Vel. C. = Hx1.2')
    plt.tight_layout()

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V2_year_1.nc').isel(obs=slice(2672, None)) as data_V2:
    #
    wc_V2 = data_V2.where(data_V2['status'] == 2)
    #
    amount_V2, _, grid_ijV2 = particles_amount(wc_V2['lon'].values.flatten(), wc_V2['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V2.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V2_plot = ax.pcolormesh(grid_ijV2[0], grid_ijV2[1], amount_V2,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV2[0], grid_ijV2[1], amount_V2, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V2 = plt.colorbar(V2_plot, ax = ax)
    cbar_V2.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V2.ax.hlines(
            lev, 
            *cbar_V2.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.0025 Pa, Ads. = 0.05, MC = 0.2, Vel. C. = N')
    plt.tight_layout()

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V3_year_1.nc').isel(obs=slice(2672, None)) as data_V3:
    #
    wc_V3 = data_V3.where(data_V3['status'] == 2)
    #
    amount_V3, _, grid_ijV3 = particles_amount(wc_V3['lon'].values.flatten(), wc_V3['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V3.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V3_plot = ax.pcolormesh(grid_ijV3[0], grid_ijV3[1], amount_V3,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV3[0], grid_ijV3[1], amount_V3, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V3 = plt.colorbar(V3_plot, ax = ax)
    cbar_V3.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V3.ax.hlines(
            lev, 
            *cbar_V3.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.005 Pa, Ads. = 0.05, MC = 0.2, Vel. C. = Hx1.2')
    plt.tight_layout()

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V4_year_1.nc').isel(obs=slice(2672, None)) as data_V4:
    #
    wc_V4 = data_V4.where(data_V4['status'] == 2)
    #
    amount_V4, _, grid_ijV4 = particles_amount(wc_V4['lon'].values.flatten(), wc_V4['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V4.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V4_plot = ax.pcolormesh(grid_ijV4[0], grid_ijV4[1], amount_V4,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV4[0], grid_ijV4[1], amount_V4, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V4 = plt.colorbar(V4_plot, ax = ax)
    cbar_V4.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V4.ax.hlines(
            lev, 
            *cbar_V4.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.001 Pa, Ads. = 0.01, MC = 0.2, Vel. C. = Hx1.2')
    plt.tight_layout()

# %%
with xr.open_dataset('/home/vvalenzuela/MOAD/Ocean_Parcels/Results_Final_Versions/Simulation_V5_year_1.nc').isel(obs=slice(2672, None)) as data_V5:
    #
    wc_V5 = data_V5.where(data_V5['status'] == 2)
    #
    amount_V5, _, grid_ijV5 = particles_amount(wc_V5['lon'].values.flatten(), wc_V5['lat'].values.flatten())
    #
    all_data = np.concatenate([
        amount_V5.values.flatten(),
    ])
    vmin = np.nanmin(all_data[all_data > 0])  # avoid zeros for LogNorm
    vmax = np.nanmax(all_data)
    norm = colors.LogNorm(vmin=vmin, vmax=10e4)    
    #
    #
    levels = [1, 10e0, 10e1, 10e2, 10e3, 10e4, 10e5]
    #
    fig, ax = plt.subplots(figsize = (7,9))
    ax.pcolormesh(mask['tmask'][0][0], cmap = cmap)
    #ax[0].contour(bathy['Bathymetry'], cmap = 'Greys')
    V5_plot = ax.pcolormesh(grid_ijV5[0], grid_ijV5[1], amount_V5,
                    norm=norm, 
                    cmap = 'RdPu', alpha = .5)
    #
    ax.contour(grid_ijV5[0], grid_ijV5[1], amount_V5, colors='black', levels = levels
                ,linewidths=0.7, linestyles='solid')
    #
    plot_polygon(polygon_N1, ax=ax, color = 'b', label = 'Region N1', fill=False)
    plot_polygon(polygon_S1, ax=ax, color = 'r', label = 'Region S1', fill=False)
    #

    cbar_V5 = plt.colorbar(V5_plot, ax = ax)
    cbar_V5.set_label('Particle Counts October 2007')
    for lev in levels:
        cbar_V5.ax.hlines(
            lev, 
            *cbar_V5.ax.get_xlim(),   # span full width
            colors='black',
            linewidth=1
        )
    #

    ax.set_aspect(1.14)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend(loc = 'lower right')    
    #
    ax.set_title(r'$\tau_c$=0.001 Pa, Ads. = 0.1, MC = 0.2, Vel. C. = Hx1.2')
    plt.tight_layout()
